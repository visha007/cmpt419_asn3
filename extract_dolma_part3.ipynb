# %%
import pandas as pd
import numpy as np
import random

# %%
rand_sample_count = 10 # The number of random samples we want from our dataset
file_loc="dolma_samples_part2.xlsx" #The file path to the data you want to sample
the_sheet_name="dolma_rand_samples_part3.xlsx" #The Excel Sheet name we want to have for our randum samples
rand_samples = []

data=pd.read_excel(file_loc,usecols="A:B")
data.reset_index()

total_row_count = data.count()
total_row_count = total_row_count["text"]
print(f"Total Rows = {total_row_count}")

max_index=data.index.max()
min_index=data.index.min()
print(f" Index(min,max) = ({min_index, max_index})")
print(data)

for i in range(rand_sample_count):
    sample_index=random.randint(min_index,max_index)
    print(f"sampel_index={sample_index}")
    text=data["text"][sample_index]
    url=data["url"][sample_index]
    print(rand_sample)
    rand_sample = {
        "text":text,
        "url":url
    }
    rand_samples.append(rand_sample)

print(rand_sample)

samples_df = pd.DataFrame(rand_samples)

samples_df.to_excel(exce=the_sheet_name,header=True, index=False)
# Out:
# Total Rows = 381
#  Index(min,max) = ((0, 380))
#                                                   text  \
# 0    Like everyone else who owns a KZ400 trying to ...
# 1    We like sharing information and our contacts.\...
# 2    Dr. John E. Sarno's Healing Back Pain is a New...
# 3    Understanding political accountability in a st...
# 4    What is a Honeypot ?\nIn recent years, the Int...
# ..                                                 ...
# 376  timbers was analyzed. The timber; Erthrophleum...
# 377  This technique is useful for curved structures...
# 378  Okay, I am working on another Twilight 2000 co...
# 379  I installed the MS edge d/l blocker tool kit, ...
# 380  theorists will benefit a lesbian Doing Busines...
#
#                                                    url
# 0    http://7thgeardesigns.com/products/carb_holder...
# 1         http://artisticphotoexpression.com/links.htm
# 2              http://fastbrowser.net/zzB000FA5SJS.htm
# ...
